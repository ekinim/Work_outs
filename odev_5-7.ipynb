# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine=create_engine('mysql+mysqlconnector://odev:DataJarLabs@localhost/sakila')

baglanti=engine.connect()

# %%
veri=pd.read_sql_query('SELECT first_name AS Adi, last_name AS Soyadi FROM customer', con=baglanti)

# %%
veri
# Out:
#            Adi     Soyadi
# 0         MARY      SMITH
# 1     PATRICIA    JOHNSON
# 2        LINDA   WILLIAMS
# 3      BARBARA      JONES
# 4    ELIZABETH      BROWN
# 5     JENNIFER      DAVIS
# 6        MARIA     MILLER
# 7        SUSAN     WILSON
# 8     MARGARET      MOORE
# 9      DOROTHY     TAYLOR
# 10        LISA   ANDERSON
# 11       NANCY     THOMAS
# 12       KAREN    JACKSON
# 13       BETTY      WHITE
# 14       HELEN     HARRIS
# 15      SANDRA     MARTIN
# 16       DONNA   THOMPSON
# 17       CAROL     GARCIA
# 18        RUTH   MARTINEZ
# 19      SHARON   ROBINSON
# 20    MICHELLE      CLARK
# 21       LAURA  RODRIGUEZ
# 22       SARAH      LEWIS
# 23    KIMBERLY        LEE
# 24     DEBORAH     WALKER
# 25     JESSICA       HALL
# 26     SHIRLEY      ALLEN
# 27     CYNTHIA      YOUNG
# 28      ANGELA  HERNANDEZ
# 29     MELISSA       KING
# ..         ...        ...
# 569       IVAN   CROMWELL
# 570    JOHNNIE   CHISHOLM
# 571     SIDNEY   BURLESON
# ...
